# %%
import numpy as np
import pandas as pd

import pickle
import json

from datetime import date

import catboost
from catboost import CatBoostClassifier

from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

# %% [markdown]
# Here we would like to begin training a few different models. First lay out our choice of models and why they were selected and then begin training for later comparison.

# %% [markdown]
# First let's read in our pre-processed training data:

# %%
X_train_minmax = np.load('data/data_train.npy')
y_train = np.load('data/labels_train.npy',)

# %% [markdown]
# #### Model selection

# %% [markdown]
# I am going to choose 3 models to train, test and compare on:
#
# 1. `Random Forest classifier`
# 2. `XGBoost`
# 3. `CatBoost` - I wanted to try this out as I hadn't used it before and saw this problem with lots of categorical variables as a good chance

# %% [markdown]
# #### RandomizedSearch

# %% [markdown]
# Before doing a proper training run, we will want to optimize the hyperparameters of our different models. So we will do a "randomized" parameter search, which will train a number of models with random different combinations over a range of hyperparameters and will return the hyperparameters which optmize a chosen `score` method best. The search will also apply `cross validation` to help determine the model with best parameters to use.
#
# I have chosen to use RandomizedSearch over GridSearch for time reasons as I didn't have a great understanding of the ball park range of parameters that would lead to the models performing well. So using random search let me explore a larger range of parameters more quickly

# %% [markdown]
# ## `Random Forest classifier`

# %%
RFclf = RandomForestClassifier()

# %%
parameters = {'n_estimators': [int(x) for x in np.linspace(start = 100, stop = 1800, num = 100)],
              'max_features': ['auto', 'sqrt'],
              'max_depth': [int(x) for x in np.linspace(30, 90, num = 11)] + [None],
              'min_samples_split': [2, 5],
              'min_samples_leaf': [1, 2]}

# %%
random_search_RF = RandomizedSearchCV(estimator = RFclf,
                                      param_distributions = parameters,
                                      cv = 5,
                                      n_iter=100,
                                      scoring = 'roc_auc',
                                      verbose=True, 
                                      n_jobs = -1)

# %% [markdown]
# I have chosen the `roc_auc` score as the `score` to optmize as I want to have the best performance possible on a combination of both the positive and negative class.

# %%
random_search_RF.fit(X_train_minmax, y_test)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'max_depth': [30, 36, 42, 48, 54, 60,
#                                                       66, 72, 78, 84, 90,
#                                                       None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2],
#                                         'min_samples_split': [2, 5],
#                                         'n_estimators': [100, 117, 134, 151,
#                                                          168, 185, 203, 220,
#                                                          237, 254, 271, 288,
#                                                          306, 323, 340, 357,
#                                                          374, 391, 409, 426,
#                                                          443, 460, 477, 494,
#                                                          512, 529, 546, 563,
#                                                          580, 597, ...]},
#                    scoring='roc_auc', verbose=2)

# %%
rf_params = rf_random.best_params_
print(rf_params)
# Out:
# {'n_estimators': 1800, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': 90, 'bootstrap': True}

# %% [markdown]
# Save params:

# %%
with open(f'params/RF-{date.today()}.json', 'w') as fp:
    json.dump(rf_params, fp)

# %% [markdown]
# Train:

# %%
RFclf = RandomForestClassifier(n_estimators=rf_params['n_estimators'],
                               min_samples_split=rf_params['min_samples_split'],
                               min_samples_leaf=rf_params['min_samples_leaf'],
                               max_features=rf_params['max_features'],
                               max_depth=rf_params['max_depth'],
                               bootstrap=rf_params['bootstrap'])

# %%
RFclf.fit(X_train_minmax, y_train)
# Out:
# RandomForestClassifier(max_depth=90, max_features='sqrt', min_samples_leaf=2,
#                        n_estimators=1800)

# %% [markdown]
# Save model:

# %%
pickle.dump(RFclf, open(f'models/RF-{date.today()}.pkl', 'wb'))

# %%
pickle.dump(RFclf, open(f'models/RF-2023-01-18.pkl', 'wb'))

# %% [markdown]
# ## `XGBoost`

# %%
XGBoost = GradientBoostingClassifier()

# %% [markdown]
# There are more parameters that could have been chosen, but only selected a few to reduce complexity and save time. These parameters were chosen to try and reduce overfitting

# %%
parameters = {
    'max_depth': range (2, 5, 1),
    'n_estimators': range(60, 220, 40),
    'learning_rate': [0.2, 0.1, 0.01, 0.05],
    'subsample': [0.1, 0.2, 0.5, 0.7, 1.]
}

# %%
grid_search = RandomizedSearchCV(
    estimator=XGBoost,
    param_distributions=parameters,
    scoring = 'roc_auc',
    n_iter=100,
    n_jobs = -1,
    cv = 5,
    verbose=True
)

# %%
grid_search.fit(X_train_minmax, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# RandomizedSearchCV(cv=5, estimator=GradientBoostingClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'learning_rate': [0.2, 0.1, 0.01, 0.05],
#                                         'max_depth': range(2, 5),
#                                         'n_estimators': range(60, 220, 40),
#                                         'subsample': [0.1, 0.2, 0.5, 0.7, 1.0]},
#                    scoring='roc_auc', verbose=True)

# %%
XGparams = grid_search.best_params_
print(XGparams)
# Out:
# {'subsample': 1.0, 'n_estimators': 100, 'max_depth': 4, 'learning_rate': 0.2}

# %% [markdown]
# Save params:

# %%
with open(f'params/XGBoost-{date.today()}.json', 'w') as fp:
    json.dump(XGparams, fp)

# %%
with open(f'params/XGBoost-2023-01-18.json', 'w') as fp:
    json.dump(XGparams, fp)

# %% [markdown]
# Train:

# %%
XGBoost = GradientBoostingClassifier(learning_rate=XGparams['learning_rate'],
                                     max_depth=XGparams['max_depth'], 
                                     n_estimators=XGparams['n_estimators'], 
                                     subsample=XGparams['subsample'])
XGBoost.fit(X_train_minmax, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.2, max_depth=4)

# %% [markdown]
# Save model:

# %%
pickle.dump(XGBoost, open(f'models/XGBoost-{date.today()}.pkl', 'wb'))

# %% [markdown]
# ## `CatBoost`

# %% [markdown]
# Read in our data in categorical form to try train on CatBoost

# %%
X_train_CB = pd.read_csv('data/train_data_cat.csv')
y_train_CB = pd.read_csv('data/train_labels_cat.csv')

# %%
cat_features = list(range(0, X_train_CB.shape[1]))

# %%
params = {
    'learning_rate': [0.05, 0.07, 0.09],
    'depth': [5, 6, 7],
    'l2_leaf_reg': [1, 3, 5, 7],
    'grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide']
}

# %%
train_pool = catboost.Pool(X_train_CB, label=y_train_CB['wage'], cat_features=cat_features)

# %%
CBoost.randomized_search(params, n_iter=5, X=train_pool)

# %% [markdown]
# Save params:

# %%
CBoost_params = {'depth': 6,
  'l2_leaf_reg': 1,
  'learning_rate': 0.05,
  'grow_policy': 'SymmetricTree'}

with open(f'params/CBoost-2023-01-20.json', 'w') as fp:
    json.dump(CBoost_params, fp)

# %% [markdown]
# Train:

# %%
CBoost = CatBoostClassifier(depth=CBoost_params['depth'],
                            learning_rate=CBoost_params['learning_rate'],
                            l2_leaf_reg=CBoost_params['l2_leaf_reg'],
                            grow_policy=CBoost_params['grow_policy'])
# Fit 
CBoost.fit(X_train_CB, y_train_CB, cat_features)
# Out:
# 0:	learn: 0.6504355	total: 445ms	remaining: 7m 24s
# 1:	learn: 0.6107876	total: 859ms	remaining: 7m 8s
# 2:	learn: 0.5739641	total: 1.28s	remaining: 7m 7s
# 3:	learn: 0.5429564	total: 1.54s	remaining: 6m 23s
# 4:	learn: 0.5167021	total: 1.83s	remaining: 6m 4s
# 5:	learn: 0.4934616	total: 2.1s	remaining: 5m 47s
# 6:	learn: 0.4733071	total: 2.35s	remaining: 5m 32s
# 7:	learn: 0.4561010	total: 2.56s	remaining: 5m 17s
# 8:	learn: 0.4419967	total: 2.79s	remaining: 5m 7s
# 9:	learn: 0.4266074	total: 3.05s	remaining: 5m 2s
# 10:	learn: 0.4157652	total: 3.34s	remaining: 5m
# 11:	learn: 0.4059716	total: 3.69s	remaining: 5m 3s
# 12:	learn: 0.3973174	total: 4s	remaining: 5m 3s
# 13:	learn: 0.3902136	total: 4.3s	remaining: 5m 3s
# 14:	learn: 0.3826012	total: 4.61s	remaining: 5m 2s
# 15:	learn: 0.3764542	total: 4.96s	remaining: 5m 4s
# 16:	learn: 0.3706479	total: 5.27s	remaining: 5m 4s
# 17:	learn: 0.3640497	total: 5.54s	remaining: 5m 2s
# 18:	learn: 0.3595833	total: 5.91s	remaining: 5m 5s
# 19:	learn: 0.3557479	total: 6.21s	remaining: 5m 4s
# 20:	learn: 0.3520997	total: 6.46s	remaining: 5m 1s
# 21:	learn: 0.3487156	total: 6.88s	remaining: 5m 5s
# 22:	learn: 0.3453556	total: 7.24s	remaining: 5m 7s
# 23:	learn: 0.3428039	total: 7.5s	remaining: 5m 5s
# 24:	learn: 0.3402592	total: 7.85s	remaining: 5m 6s
# 25:	learn: 0.3379500	total: 8.25s	remaining: 5m 9s
# 26:	learn: 0.3354847	total: 8.66s	remaining: 5m 12s
# 27:	learn: 0.3334929	total: 9.08s	remaining: 5m 15s
# 28:	learn: 0.3319475	total: 9.4s	remaining: 5m 14s
# 29:	learn: 0.3294993	total: 9.71s	remaining: 5m 14s
# 30:	learn: 0.3280932	total: 10s	remaining: 5m 13s
# 31:	learn: 0.3265305	total: 10.3s	remaining: 5m 11s
# 32:	learn: 0.3252176	total: 10.6s	remaining: 5m 10s
# 33:	learn: 0.3237573	total: 11s	remaining: 5m 11s
# 34:	learn: 0.3224684	total: 11.3s	remaining: 5m 12s
# 35:	learn: 0.3212406	total: 11.7s	remaining: 5m 13s
# 36:	learn: 0.3201834	total: 12.1s	remaining: 5m 14s
# 37:	learn: 0.3188072	total: 12.5s	remaining: 5m 15s
# 38:	learn: 0.3178117	total: 12.8s	remaining: 5m 14s
# 39:	learn: 0.3166459	total: 13.1s	remaining: 5m 15s
# 40:	learn: 0.3137373	total: 13.5s	remaining: 5m 14s
# 41:	learn: 0.3127151	total: 13.9s	remaining: 5m 16s
# 42:	learn: 0.3110607	total: 14.2s	remaining: 5m 16s
# 43:	learn: 0.3092907	total: 14.6s	remaining: 5m 16s
# 44:	learn: 0.3082195	total: 14.9s	remaining: 5m 17s
# 45:	learn: 0.3075434	total: 15.3s	remaining: 5m 17s
# 46:	learn: 0.3067850	total: 15.8s	remaining: 5m 20s
# 47:	learn: 0.3052242	total: 16.2s	remaining: 5m 20s
# 48:	learn: 0.3046248	total: 16.5s	remaining: 5m 21s
# 49:	learn: 0.3040900	total: 17s	remaining: 5m 22s
# 50:	learn: 0.3034959	total: 17.4s	remaining: 5m 24s
# 51:	learn: 0.3028438	total: 17.8s	remaining: 5m 24s
# 52:	learn: 0.3022430	total: 18.1s	remaining: 5m 23s
# 53:	learn: 0.3017300	total: 18.5s	remaining: 5m 23s
# 54:	learn: 0.3006506	total: 19s	remaining: 5m 26s
# 55:	learn: 0.3000904	total: 19.5s	remaining: 5m 29s
# 56:	learn: 0.2997120	total: 20s	remaining: 5m 31s
# 57:	learn: 0.2992477	total: 20.4s	remaining: 5m 31s
# 58:	learn: 0.2988816	total: 20.8s	remaining: 5m 31s
# 59:	learn: 0.2984298	total: 21.7s	remaining: 5m 40s
# 60:	learn: 0.2980810	total: 22.2s	remaining: 5m 42s
# 61:	learn: 0.2977084	total: 22.6s	remaining: 5m 41s
# 62:	learn: 0.2972355	total: 23s	remaining: 5m 42s
# 63:	learn: 0.2969395	total: 23.3s	remaining: 5m 41s
# 64:	learn: 0.2966390	total: 23.8s	remaining: 5m 41s
# 65:	learn: 0.2963931	total: 24.2s	remaining: 5m 42s
# 66:	learn: 0.2961026	total: 24.6s	remaining: 5m 42s
# 67:	learn: 0.2958022	total: 25s	remaining: 5m 43s
# 68:	learn: 0.2949865	total: 25.4s	remaining: 5m 42s
# 69:	learn: 0.2946348	total: 25.8s	remaining: 5m 43s
# 70:	learn: 0.2943531	total: 26.3s	remaining: 5m 43s
# 71:	learn: 0.2940216	total: 26.7s	remaining: 5m 44s
# 72:	learn: 0.2936847	total: 27.1s	remaining: 5m 43s
# 73:	learn: 0.2932792	total: 27.5s	remaining: 5m 44s
# 74:	learn: 0.2929915	total: 28.1s	remaining: 5m 45s
# 75:	learn: 0.2927132	total: 28.5s	remaining: 5m 46s
# 76:	learn: 0.2922467	total: 28.8s	remaining: 5m 45s
# 77:	learn: 0.2920347	total: 29.2s	remaining: 5m 45s
# 78:	learn: 0.2916607	total: 29.6s	remaining: 5m 45s
# 79:	learn: 0.2911702	total: 30.1s	remaining: 5m 45s
# 80:	learn: 0.2906586	total: 30.4s	remaining: 5m 44s
# 81:	learn: 0.2896126	total: 31s	remaining: 5m 46s
# 82:	learn: 0.2888821	total: 31.5s	remaining: 5m 47s
# 83:	learn: 0.2886546	total: 31.9s	remaining: 5m 47s
# 84:	learn: 0.2884952	total: 32.3s	remaining: 5m 47s
# 85:	learn: 0.2882289	total: 32.7s	remaining: 5m 48s
# 86:	learn: 0.2873713	total: 33.2s	remaining: 5m 48s
# 87:	learn: 0.2869927	total: 33.7s	remaining: 5m 49s
# 88:	learn: 0.2868122	total: 34.1s	remaining: 5m 49s
# 89:	learn: 0.2859425	total: 34.5s	remaining: 5m 48s
# 90:	learn: 0.2850665	total: 34.9s	remaining: 5m 48s
# 91:	learn: 0.2848437	total: 35.4s	remaining: 5m 49s
# 92:	learn: 0.2846712	total: 35.9s	remaining: 5m 50s
# 93:	learn: 0.2843666	total: 36.4s	remaining: 5m 51s
# 94:	learn: 0.2841807	total: 37s	remaining: 5m 52s
# 95:	learn: 0.2838899	total: 37.4s	remaining: 5m 52s
# 96:	learn: 0.2832994	total: 37.8s	remaining: 5m 52s
# 97:	learn: 0.2829319	total: 38.2s	remaining: 5m 51s
# 98:	learn: 0.2825816	total: 38.7s	remaining: 5m 52s
# 99:	learn: 0.2808355	total: 39.1s	remaining: 5m 52s
# 100:	learn: 0.2802545	total: 39.6s	remaining: 5m 52s
# 101:	learn: 0.2795504	total: 40.1s	remaining: 5m 52s
# 102:	learn: 0.2793997	total: 40.5s	remaining: 5m 53s
# 103:	learn: 0.2781292	total: 41.1s	remaining: 5m 54s
# 104:	learn: 0.2773447	total: 41.5s	remaining: 5m 53s
# 105:	learn: 0.2769779	total: 41.9s	remaining: 5m 53s
# 106:	learn: 0.2767332	total: 42.4s	remaining: 5m 53s
# 107:	learn: 0.2764234	total: 42.8s	remaining: 5m 53s
# 108:	learn: 0.2762966	total: 43.3s	remaining: 5m 53s
# 109:	learn: 0.2760700	total: 43.7s	remaining: 5m 53s
# 110:	learn: 0.2758655	total: 44.1s	remaining: 5m 53s
# 111:	learn: 0.2746998	total: 44.5s	remaining: 5m 53s
# 112:	learn: 0.2738433	total: 45s	remaining: 5m 52s
# 113:	learn: 0.2732924	total: 45.4s	remaining: 5m 52s
# 114:	learn: 0.2726274	total: 45.9s	remaining: 5m 53s
# 115:	learn: 0.2725116	total: 46.3s	remaining: 5m 52s
# 116:	learn: 0.2717056	total: 46.8s	remaining: 5m 53s
# 117:	learn: 0.2715350	total: 47.3s	remaining: 5m 53s
# 118:	learn: 0.2713783	total: 47.7s	remaining: 5m 53s
# 119:	learn: 0.2712090	total: 48.2s	remaining: 5m 53s
# 120:	learn: 0.2710541	total: 48.7s	remaining: 5m 53s
# 121:	learn: 0.2709384	total: 49.2s	remaining: 5m 53s
# 122:	learn: 0.2708361	total: 49.6s	remaining: 5m 53s
# 123:	learn: 0.2704610	total: 50.2s	remaining: 5m 54s
# 124:	learn: 0.2700403	total: 50.6s	remaining: 5m 54s
# 125:	learn: 0.2692947	total: 51s	remaining: 5m 53s
# 126:	learn: 0.2686801	total: 51.5s	remaining: 5m 53s
# 127:	learn: 0.2683431	total: 52s	remaining: 5m 54s
# 128:	learn: 0.2682268	total: 52.5s	remaining: 5m 54s
# 129:	learn: 0.2680829	total: 52.9s	remaining: 5m 53s
# 130:	learn: 0.2676597	total: 53.3s	remaining: 5m 53s
# 131:	learn: 0.2675389	total: 53.7s	remaining: 5m 53s
# 132:	learn: 0.2673974	total: 54.2s	remaining: 5m 53s
# 133:	learn: 0.2673052	total: 54.6s	remaining: 5m 52s
# 134:	learn: 0.2669423	total: 55.1s	remaining: 5m 53s
# 135:	learn: 0.2663863	total: 55.6s	remaining: 5m 52s
# 136:	learn: 0.2660507	total: 56s	remaining: 5m 52s
# 137:	learn: 0.2659189	total: 56.4s	remaining: 5m 52s
# 138:	learn: 0.2658248	total: 56.9s	remaining: 5m 52s
# 139:	learn: 0.2657217	total: 57.3s	remaining: 5m 52s
# 140:	learn: 0.2656358	total: 57.9s	remaining: 5m 52s
# 141:	learn: 0.2655244	total: 58.3s	remaining: 5m 52s
# 142:	learn: 0.2654376	total: 58.7s	remaining: 5m 51s
# 143:	learn: 0.2649830	total: 59.1s	remaining: 5m 51s
# 144:	learn: 0.2640750	total: 59.5s	remaining: 5m 51s
# 145:	learn: 0.2639796	total: 1m	remaining: 5m 51s
# 146:	learn: 0.2638272	total: 1m	remaining: 5m 51s
# 147:	learn: 0.2637213	total: 1m	remaining: 5m 50s
# 148:	learn: 0.2635789	total: 1m 1s	remaining: 5m 50s
# 149:	learn: 0.2630126	total: 1m 1s	remaining: 5m 50s
# 150:	learn: 0.2629097	total: 1m 2s	remaining: 5m 50s
# 151:	learn: 0.2621573	total: 1m 2s	remaining: 5m 49s
# 152:	learn: 0.2620511	total: 1m 3s	remaining: 5m 49s
# 153:	learn: 0.2619473	total: 1m 3s	remaining: 5m 50s
# 154:	learn: 0.2614065	total: 1m 4s	remaining: 5m 49s
# 155:	learn: 0.2606407	total: 1m 4s	remaining: 5m 48s
# 156:	learn: 0.2605290	total: 1m 4s	remaining: 5m 48s
# 157:	learn: 0.2604291	total: 1m 5s	remaining: 5m 48s
# 158:	learn: 0.2603217	total: 1m 5s	remaining: 5m 48s
# 159:	learn: 0.2602593	total: 1m 6s	remaining: 5m 48s
# 160:	learn: 0.2601658	total: 1m 6s	remaining: 5m 48s
# 161:	learn: 0.2600676	total: 1m 7s	remaining: 5m 48s
# 162:	learn: 0.2595922	total: 1m 7s	remaining: 5m 48s
# 163:	learn: 0.2595386	total: 1m 8s	remaining: 5m 47s
# 164:	learn: 0.2593037	total: 1m 8s	remaining: 5m 47s
# 165:	learn: 0.2592047	total: 1m 9s	remaining: 5m 47s
# 166:	learn: 0.2587114	total: 1m 9s	remaining: 5m 46s
# 167:	learn: 0.2586337	total: 1m 10s	remaining: 5m 47s
# 168:	learn: 0.2582650	total: 1m 10s	remaining: 5m 46s
# 169:	learn: 0.2581631	total: 1m 10s	remaining: 5m 46s
# 170:	learn: 0.2577962	total: 1m 11s	remaining: 5m 46s
# 171:	learn: 0.2577084	total: 1m 11s	remaining: 5m 46s
# 172:	learn: 0.2576086	total: 1m 12s	remaining: 5m 45s
# 173:	learn: 0.2575220	total: 1m 12s	remaining: 5m 46s
# 174:	learn: 0.2574400	total: 1m 13s	remaining: 5m 45s
# 175:	learn: 0.2573544	total: 1m 13s	remaining: 5m 45s
# 176:	learn: 0.2572870	total: 1m 14s	remaining: 5m 44s
# 177:	learn: 0.2569918	total: 1m 14s	remaining: 5m 44s
# 178:	learn: 0.2569294	total: 1m 14s	remaining: 5m 43s
# 179:	learn: 0.2568404	total: 1m 15s	remaining: 5m 43s
# 180:	learn: 0.2567568	total: 1m 15s	remaining: 5m 43s
# 181:	learn: 0.2564041	total: 1m 16s	remaining: 5m 42s
# 182:	learn: 0.2562703	total: 1m 16s	remaining: 5m 42s
# 183:	learn: 0.2560687	total: 1m 17s	remaining: 5m 42s
# 184:	learn: 0.2560072	total: 1m 17s	remaining: 5m 42s
# 185:	learn: 0.2558472	total: 1m 18s	remaining: 5m 42s
# 186:	learn: 0.2557725	total: 1m 18s	remaining: 5m 42s
# 187:	learn: 0.2556760	total: 1m 19s	remaining: 5m 42s
# 188:	learn: 0.2554264	total: 1m 19s	remaining: 5m 41s
# 189:	learn: 0.2553515	total: 1m 20s	remaining: 5m 41s
# 190:	learn: 0.2552992	total: 1m 20s	remaining: 5m 40s
# 191:	learn: 0.2552396	total: 1m 20s	remaining: 5m 40s
# 192:	learn: 0.2551702	total: 1m 21s	remaining: 5m 40s
# 193:	learn: 0.2551017	total: 1m 22s	remaining: 5m 40s
# 194:	learn: 0.2546999	total: 1m 22s	remaining: 5m 40s
# 195:	learn: 0.2545512	total: 1m 22s	remaining: 5m 40s
# 196:	learn: 0.2544045	total: 1m 23s	remaining: 5m 40s
# 197:	learn: 0.2540799	total: 1m 23s	remaining: 5m 39s
# 198:	learn: 0.2536555	total: 1m 24s	remaining: 5m 39s
# 199:	learn: 0.2535322	total: 1m 24s	remaining: 5m 39s
# 200:	learn: 0.2534792	total: 1m 25s	remaining: 5m 38s
# 201:	learn: 0.2530473	total: 1m 25s	remaining: 5m 38s
# 202:	learn: 0.2529628	total: 1m 26s	remaining: 5m 37s
# 203:	learn: 0.2526133	total: 1m 26s	remaining: 5m 37s
# 204:	learn: 0.2525523	total: 1m 26s	remaining: 5m 37s
# 205:	learn: 0.2521744	total: 1m 27s	remaining: 5m 37s
# 206:	learn: 0.2520887	total: 1m 28s	remaining: 5m 37s
# 207:	learn: 0.2520071	total: 1m 28s	remaining: 5m 38s
# 208:	learn: 0.2519634	total: 1m 29s	remaining: 5m 37s
# 209:	learn: 0.2519155	total: 1m 29s	remaining: 5m 37s
# 210:	learn: 0.2518420	total: 1m 30s	remaining: 5m 37s
# 211:	learn: 0.2513027	total: 1m 30s	remaining: 5m 37s
# 212:	learn: 0.2508814	total: 1m 31s	remaining: 5m 37s
# 213:	learn: 0.2508038	total: 1m 31s	remaining: 5m 36s
# 214:	learn: 0.2507560	total: 1m 32s	remaining: 5m 36s
# 215:	learn: 0.2507014	total: 1m 32s	remaining: 5m 36s
# 216:	learn: 0.2505299	total: 1m 33s	remaining: 5m 36s
# 217:	learn: 0.2503141	total: 1m 33s	remaining: 5m 36s
# 218:	learn: 0.2502667	total: 1m 34s	remaining: 5m 35s
# 219:	learn: 0.2500772	total: 1m 34s	remaining: 5m 35s
# 220:	learn: 0.2499916	total: 1m 35s	remaining: 5m 35s
# 221:	learn: 0.2499159	total: 1m 35s	remaining: 5m 34s
# 222:	learn: 0.2498641	total: 1m 35s	remaining: 5m 34s
# 223:	learn: 0.2497321	total: 1m 36s	remaining: 5m 34s
# 224:	learn: 0.2496616	total: 1m 36s	remaining: 5m 34s
# 225:	learn: 0.2496031	total: 1m 37s	remaining: 5m 33s
# 226:	learn: 0.2494043	total: 1m 37s	remaining: 5m 33s
# 227:	learn: 0.2493204	total: 1m 38s	remaining: 5m 32s
# 228:	learn: 0.2492494	total: 1m 38s	remaining: 5m 32s
# 229:	learn: 0.2491585	total: 1m 39s	remaining: 5m 32s
# 230:	learn: 0.2487422	total: 1m 39s	remaining: 5m 31s
# 231:	learn: 0.2486688	total: 1m 40s	remaining: 5m 31s
# 232:	learn: 0.2486292	total: 1m 40s	remaining: 5m 30s
# 233:	learn: 0.2485564	total: 1m 41s	remaining: 5m 30s
# 234:	learn: 0.2485015	total: 1m 41s	remaining: 5m 30s
# 235:	learn: 0.2482567	total: 1m 42s	remaining: 5m 30s
# 236:	learn: 0.2482079	total: 1m 42s	remaining: 5m 30s
# 237:	learn: 0.2481409	total: 1m 43s	remaining: 5m 30s
# 238:	learn: 0.2480071	total: 1m 43s	remaining: 5m 29s
# 239:	learn: 0.2477783	total: 1m 44s	remaining: 5m 29s
# 240:	learn: 0.2477104	total: 1m 44s	remaining: 5m 29s
# 241:	learn: 0.2476535	total: 1m 45s	remaining: 5m 29s
# 242:	learn: 0.2474202	total: 1m 45s	remaining: 5m 29s
# 243:	learn: 0.2472573	total: 1m 46s	remaining: 5m 28s
# 244:	learn: 0.2472054	total: 1m 46s	remaining: 5m 28s
# 245:	learn: 0.2471297	total: 1m 47s	remaining: 5m 28s
# 246:	learn: 0.2471049	total: 1m 47s	remaining: 5m 27s
# 247:	learn: 0.2468763	total: 1m 47s	remaining: 5m 27s
# 248:	learn: 0.2466939	total: 1m 48s	remaining: 5m 26s
# 249:	learn: 0.2466136	total: 1m 48s	remaining: 5m 26s
# 250:	learn: 0.2465306	total: 1m 49s	remaining: 5m 25s
# 251:	learn: 0.2464701	total: 1m 49s	remaining: 5m 25s
# 252:	learn: 0.2464061	total: 1m 50s	remaining: 5m 24s
# 253:	learn: 0.2463493	total: 1m 50s	remaining: 5m 24s
# 254:	learn: 0.2460596	total: 1m 50s	remaining: 5m 24s
# 255:	learn: 0.2459790	total: 1m 51s	remaining: 5m 23s
# 256:	learn: 0.2458915	total: 1m 51s	remaining: 5m 23s
# 257:	learn: 0.2458053	total: 1m 52s	remaining: 5m 23s
# 258:	learn: 0.2456936	total: 1m 52s	remaining: 5m 22s
# 259:	learn: 0.2456286	total: 1m 53s	remaining: 5m 22s
# 260:	learn: 0.2455274	total: 1m 53s	remaining: 5m 22s
# 261:	learn: 0.2454801	total: 1m 54s	remaining: 5m 22s
# 262:	learn: 0.2454118	total: 1m 54s	remaining: 5m 21s
# 263:	learn: 0.2451783	total: 1m 55s	remaining: 5m 21s
# 264:	learn: 0.2451093	total: 1m 55s	remaining: 5m 21s
# 265:	learn: 0.2450820	total: 1m 56s	remaining: 5m 20s
# 266:	learn: 0.2450363	total: 1m 56s	remaining: 5m 20s
# 267:	learn: 0.2449740	total: 1m 57s	remaining: 5m 20s
# 268:	learn: 0.2448504	total: 1m 57s	remaining: 5m 20s
# 269:	learn: 0.2447147	total: 1m 58s	remaining: 5m 19s
# 270:	learn: 0.2444918	total: 1m 58s	remaining: 5m 19s
# 271:	learn: 0.2443821	total: 1m 59s	remaining: 5m 18s
# 272:	learn: 0.2442687	total: 1m 59s	remaining: 5m 18s
# 273:	learn: 0.2439732	total: 1m 59s	remaining: 5m 17s
# 274:	learn: 0.2437806	total: 2m	remaining: 5m 17s
# 275:	learn: 0.2437176	total: 2m	remaining: 5m 16s
# 276:	learn: 0.2434329	total: 2m 1s	remaining: 5m 16s
# 277:	learn: 0.2433193	total: 2m 1s	remaining: 5m 15s
# 278:	learn: 0.2432588	total: 2m 2s	remaining: 5m 15s
# 279:	learn: 0.2431113	total: 2m 2s	remaining: 5m 15s
# 280:	learn: 0.2429959	total: 2m 2s	remaining: 5m 14s
# 281:	learn: 0.2426720	total: 2m 3s	remaining: 5m 13s
# 282:	learn: 0.2426164	total: 2m 3s	remaining: 5m 13s
# 283:	learn: 0.2424998	total: 2m 4s	remaining: 5m 13s
# 284:	learn: 0.2424151	total: 2m 4s	remaining: 5m 13s
# 285:	learn: 0.2423684	total: 2m 5s	remaining: 5m 12s
# 286:	learn: 0.2421359	total: 2m 5s	remaining: 5m 12s
# 287:	learn: 0.2418959	total: 2m 6s	remaining: 5m 12s
# 288:	learn: 0.2418054	total: 2m 6s	remaining: 5m 11s
# 289:	learn: 0.2416009	total: 2m 7s	remaining: 5m 11s
# 290:	learn: 0.2414918	total: 2m 7s	remaining: 5m 11s
# 291:	learn: 0.2411566	total: 2m 8s	remaining: 5m 10s
# 292:	learn: 0.2410768	total: 2m 8s	remaining: 5m 10s
# 293:	learn: 0.2410402	total: 2m 9s	remaining: 5m 9s
# 294:	learn: 0.2409685	total: 2m 9s	remaining: 5m 9s
# 295:	learn: 0.2409241	total: 2m 9s	remaining: 5m 8s
# 296:	learn: 0.2408492	total: 2m 10s	remaining: 5m 8s
# 297:	learn: 0.2408032	total: 2m 10s	remaining: 5m 8s
# 298:	learn: 0.2406458	total: 2m 11s	remaining: 5m 7s
# 299:	learn: 0.2406155	total: 2m 11s	remaining: 5m 7s
# 300:	learn: 0.2405833	total: 2m 12s	remaining: 5m 6s
# 301:	learn: 0.2404459	total: 2m 12s	remaining: 5m 6s
# 302:	learn: 0.2403730	total: 2m 13s	remaining: 5m 6s
# 303:	learn: 0.2402793	total: 2m 13s	remaining: 5m 5s
# 304:	learn: 0.2401967	total: 2m 13s	remaining: 5m 5s
# 305:	learn: 0.2401588	total: 2m 14s	remaining: 5m 4s
# 609:	learn: 0.2204640	total: 4m 59s	remaining: 3m 11s
# 610:	learn: 0.2203939	total: 5m	remaining: 3m 11s
# 611:	learn: 0.2203575	total: 5m	remaining: 3m 10s
# 612:	learn: 0.2203059	total: 5m 1s	remaining: 3m 10s
# 613:	learn: 0.2202319	total: 5m 1s	remaining: 3m 9s
# 614:	learn: 0.2201429	total: 5m 2s	remaining: 3m 9s
# 615:	learn: 0.2200567	total: 5m 2s	remaining: 3m 8s
# 616:	learn: 0.2200320	total: 5m 3s	remaining: 3m 8s
# 617:	learn: 0.2199584	total: 5m 4s	remaining: 3m 7s
# 618:	learn: 0.2199098	total: 5m 4s	remaining: 3m 7s
# 619:	learn: 0.2198937	total: 5m 5s	remaining: 3m 7s
# 620:	learn: 0.2198570	total: 5m 5s	remaining: 3m 6s
# 621:	learn: 0.2198238	total: 5m 6s	remaining: 3m 5s
# 622:	learn: 0.2197721	total: 5m 6s	remaining: 3m 5s
# 623:	learn: 0.2197267	total: 5m 6s	remaining: 3m 4s
# 624:	learn: 0.2196776	total: 5m 7s	remaining: 3m 4s
# 625:	learn: 0.2196073	total: 5m 7s	remaining: 3m 3s
# 626:	learn: 0.2194458	total: 5m 8s	remaining: 3m 3s
# 627:	learn: 0.2193230	total: 5m 8s	remaining: 3m 2s
# 628:	learn: 0.2192544	total: 5m 9s	remaining: 3m 2s
# 629:	learn: 0.2191163	total: 5m 9s	remaining: 3m 1s
# 630:	learn: 0.2190887	total: 5m 9s	remaining: 3m 1s
# 631:	learn: 0.2190193	total: 5m 10s	remaining: 3m
# 632:	learn: 0.2189853	total: 5m 10s	remaining: 3m
# 633:	learn: 0.2189540	total: 5m 11s	remaining: 2m 59s
# 634:	learn: 0.2189110	total: 5m 11s	remaining: 2m 59s
# 635:	learn: 0.2188781	total: 5m 12s	remaining: 2m 58s
# 636:	learn: 0.2188442	total: 5m 13s	remaining: 2m 58s
# 637:	learn: 0.2187153	total: 5m 13s	remaining: 2m 57s
# 638:	learn: 0.2186050	total: 5m 13s	remaining: 2m 57s
# 639:	learn: 0.2184740	total: 5m 14s	remaining: 2m 56s
# 640:	learn: 0.2184472	total: 5m 14s	remaining: 2m 56s
# 641:	learn: 0.2183456	total: 5m 15s	remaining: 2m 55s
# 642:	learn: 0.2182842	total: 5m 15s	remaining: 2m 55s
# 643:	learn: 0.2182439	total: 5m 16s	remaining: 2m 54s
# 644:	learn: 0.2181059	total: 5m 16s	remaining: 2m 54s
# 645:	learn: 0.2179178	total: 5m 17s	remaining: 2m 53s
# 646:	learn: 0.2178651	total: 5m 17s	remaining: 2m 53s
# 647:	learn: 0.2177466	total: 5m 17s	remaining: 2m 52s
# 648:	learn: 0.2177032	total: 5m 18s	remaining: 2m 52s
# 649:	learn: 0.2176870	total: 5m 18s	remaining: 2m 51s
# 650:	learn: 0.2176626	total: 5m 19s	remaining: 2m 51s
# 651:	learn: 0.2175488	total: 5m 19s	remaining: 2m 50s
# 652:	learn: 0.2175161	total: 5m 19s	remaining: 2m 50s
# 653:	learn: 0.2174410	total: 5m 20s	remaining: 2m 49s
# 654:	learn: 0.2173899	total: 5m 20s	remaining: 2m 49s
# 655:	learn: 0.2173019	total: 5m 21s	remaining: 2m 48s
# 656:	learn: 0.2172769	total: 5m 21s	remaining: 2m 47s
# 657:	learn: 0.2172492	total: 5m 22s	remaining: 2m 47s
# 658:	learn: 0.2171258	total: 5m 22s	remaining: 2m 46s
# 659:	learn: 0.2170786	total: 5m 23s	remaining: 2m 46s
# 660:	learn: 0.2170710	total: 5m 23s	remaining: 2m 45s
# 661:	learn: 0.2170298	total: 5m 23s	remaining: 2m 45s
# 662:	learn: 0.2169218	total: 5m 24s	remaining: 2m 44s
# 663:	learn: 0.2169002	total: 5m 25s	remaining: 2m 44s
# 664:	learn: 0.2168828	total: 5m 25s	remaining: 2m 44s
# 665:	learn: 0.2168400	total: 5m 26s	remaining: 2m 43s
# 666:	learn: 0.2168168	total: 5m 26s	remaining: 2m 43s
# 667:	learn: 0.2167321	total: 5m 26s	remaining: 2m 42s
# 668:	learn: 0.2166262	total: 5m 27s	remaining: 2m 41s
# 669:	learn: 0.2166092	total: 5m 27s	remaining: 2m 41s
# 670:	learn: 0.2165812	total: 5m 28s	remaining: 2m 41s
# 671:	learn: 0.2165099	total: 5m 28s	remaining: 2m 40s
# 672:	learn: 0.2164762	total: 5m 29s	remaining: 2m 39s
# 673:	learn: 0.2164476	total: 5m 29s	remaining: 2m 39s
# 674:	learn: 0.2163290	total: 5m 30s	remaining: 2m 38s
# 675:	learn: 0.2161913	total: 5m 30s	remaining: 2m 38s
# 676:	learn: 0.2161615	total: 5m 31s	remaining: 2m 37s
# 677:	learn: 0.2161391	total: 5m 31s	remaining: 2m 37s
# 678:	learn: 0.2161172	total: 5m 31s	remaining: 2m 36s
# 679:	learn: 0.2160619	total: 5m 32s	remaining: 2m 36s
# 680:	learn: 0.2160427	total: 5m 32s	remaining: 2m 35s
# 681:	learn: 0.2160000	total: 5m 33s	remaining: 2m 35s
# 682:	learn: 0.2159859	total: 5m 33s	remaining: 2m 34s
# 683:	learn: 0.2159243	total: 5m 34s	remaining: 2m 34s
# 684:	learn: 0.2158343	total: 5m 34s	remaining: 2m 33s
# 685:	learn: 0.2157569	total: 5m 35s	remaining: 2m 33s
# 686:	learn: 0.2155674	total: 5m 35s	remaining: 2m 32s
# 687:	learn: 0.2155198	total: 5m 36s	remaining: 2m 32s
# 688:	learn: 0.2154335	total: 5m 36s	remaining: 2m 31s
# 689:	learn: 0.2152507	total: 5m 37s	remaining: 2m 31s
# 690:	learn: 0.2151676	total: 5m 37s	remaining: 2m 30s
# 691:	learn: 0.2151457	total: 5m 37s	remaining: 2m 30s
# 692:	learn: 0.2150375	total: 5m 38s	remaining: 2m 29s
# 693:	learn: 0.2149836	total: 5m 38s	remaining: 2m 29s
# 694:	learn: 0.2149350	total: 5m 39s	remaining: 2m 28s
# 695:	learn: 0.2148964	total: 5m 39s	remaining: 2m 28s
# 696:	learn: 0.2147710	total: 5m 39s	remaining: 2m 27s
# 697:	learn: 0.2147008	total: 5m 40s	remaining: 2m 27s
# 698:	learn: 0.2146153	total: 5m 40s	remaining: 2m 26s
# 699:	learn: 0.2145633	total: 5m 41s	remaining: 2m 26s
# 700:	learn: 0.2145309	total: 5m 41s	remaining: 2m 25s
# 701:	learn: 0.2145070	total: 5m 42s	remaining: 2m 25s
# 702:	learn: 0.2144785	total: 5m 42s	remaining: 2m 24s
# 703:	learn: 0.2144511	total: 5m 42s	remaining: 2m 24s
# 704:	learn: 0.2144361	total: 5m 43s	remaining: 2m 23s
# 705:	learn: 0.2143335	total: 5m 43s	remaining: 2m 23s
# 706:	learn: 0.2142543	total: 5m 44s	remaining: 2m 22s
# 707:	learn: 0.2142258	total: 5m 44s	remaining: 2m 22s
# 708:	learn: 0.2142069	total: 5m 45s	remaining: 2m 21s
# 709:	learn: 0.2141562	total: 5m 45s	remaining: 2m 21s
# 710:	learn: 0.2141381	total: 5m 46s	remaining: 2m 20s
# 711:	learn: 0.2141149	total: 5m 46s	remaining: 2m 20s
# 712:	learn: 0.2140922	total: 5m 47s	remaining: 2m 19s
# 713:	learn: 0.2140447	total: 5m 47s	remaining: 2m 19s
# 714:	learn: 0.2140060	total: 5m 48s	remaining: 2m 18s
# 715:	learn: 0.2139701	total: 5m 48s	remaining: 2m 18s
# 716:	learn: 0.2137989	total: 5m 49s	remaining: 2m 17s
# 717:	learn: 0.2137790	total: 5m 49s	remaining: 2m 17s
# 718:	learn: 0.2137462	total: 5m 50s	remaining: 2m 16s
# 719:	learn: 0.2137216	total: 5m 50s	remaining: 2m 16s
# 720:	learn: 0.2136942	total: 5m 50s	remaining: 2m 15s
# 721:	learn: 0.2136826	total: 5m 51s	remaining: 2m 15s
# 722:	learn: 0.2136559	total: 5m 51s	remaining: 2m 14s
# 723:	learn: 0.2135735	total: 5m 52s	remaining: 2m 14s
# 724:	learn: 0.2135389	total: 5m 52s	remaining: 2m 13s
# 725:	learn: 0.2135165	total: 5m 53s	remaining: 2m 13s
# 726:	learn: 0.2134663	total: 5m 53s	remaining: 2m 12s
# 727:	learn: 0.2134501	total: 5m 54s	remaining: 2m 12s
# 728:	learn: 0.2133687	total: 5m 54s	remaining: 2m 11s
# 729:	learn: 0.2133549	total: 5m 55s	remaining: 2m 11s
# 730:	learn: 0.2133051	total: 5m 55s	remaining: 2m 10s
# 731:	learn: 0.2132833	total: 5m 56s	remaining: 2m 10s
# 732:	learn: 0.2132584	total: 5m 56s	remaining: 2m 10s
# 733:	learn: 0.2132045	total: 5m 57s	remaining: 2m 9s
# 734:	learn: 0.2131654	total: 5m 57s	remaining: 2m 9s
# 735:	learn: 0.2131154	total: 5m 58s	remaining: 2m 8s
# 736:	learn: 0.2130898	total: 5m 58s	remaining: 2m 8s
# 737:	learn: 0.2130604	total: 5m 59s	remaining: 2m 7s
# 738:	learn: 0.2130463	total: 5m 59s	remaining: 2m 7s
# 739:	learn: 0.2130273	total: 6m	remaining: 2m 6s
# 740:	learn: 0.2130008	total: 6m	remaining: 2m 6s
# 741:	learn: 0.2129317	total: 6m 1s	remaining: 2m 5s
# 742:	learn: 0.2129089	total: 6m 1s	remaining: 2m 5s
# 743:	learn: 0.2128794	total: 6m 2s	remaining: 2m 4s
# 744:	learn: 0.2127884	total: 6m 2s	remaining: 2m 4s
# 745:	learn: 0.2127450	total: 6m 3s	remaining: 2m 3s
# 746:	learn: 0.2127269	total: 6m 3s	remaining: 2m 3s
# 747:	learn: 0.2127161	total: 6m 4s	remaining: 2m 2s
# 748:	learn: 0.2127028	total: 6m 4s	remaining: 2m 2s
# 749:	learn: 0.2126781	total: 6m 4s	remaining: 2m 1s
# 750:	learn: 0.2126423	total: 6m 5s	remaining: 2m 1s
# 751:	learn: 0.2125760	total: 6m 5s	remaining: 2m
# 752:	learn: 0.2125561	total: 6m 6s	remaining: 2m
# 753:	learn: 0.2124919	total: 6m 6s	remaining: 1m 59s
# 754:	learn: 0.2124119	total: 6m 7s	remaining: 1m 59s
# 755:	learn: 0.2123929	total: 6m 7s	remaining: 1m 58s
# 756:	learn: 0.2123668	total: 6m 8s	remaining: 1m 58s
# 757:	learn: 0.2123442	total: 6m 8s	remaining: 1m 57s
# 758:	learn: 0.2123202	total: 6m 9s	remaining: 1m 57s
# 759:	learn: 0.2122050	total: 6m 9s	remaining: 1m 56s
# 760:	learn: 0.2121128	total: 6m 10s	remaining: 1m 56s
# 761:	learn: 0.2119885	total: 6m 10s	remaining: 1m 55s
# 762:	learn: 0.2119669	total: 6m 11s	remaining: 1m 55s
# 763:	learn: 0.2119210	total: 6m 11s	remaining: 1m 54s
# 764:	learn: 0.2118820	total: 6m 12s	remaining: 1m 54s
# 765:	learn: 0.2118087	total: 6m 12s	remaining: 1m 53s
# 766:	learn: 0.2117694	total: 6m 13s	remaining: 1m 53s
# 767:	learn: 0.2117290	total: 6m 13s	remaining: 1m 52s
# 768:	learn: 0.2116934	total: 6m 14s	remaining: 1m 52s
# 769:	learn: 0.2116594	total: 6m 14s	remaining: 1m 51s
# 770:	learn: 0.2116380	total: 6m 15s	remaining: 1m 51s
# 771:	learn: 0.2115736	total: 6m 16s	remaining: 1m 51s
# 772:	learn: 0.2115607	total: 6m 16s	remaining: 1m 50s
# 773:	learn: 0.2115288	total: 6m 17s	remaining: 1m 50s
# 774:	learn: 0.2115201	total: 6m 17s	remaining: 1m 49s
# 775:	learn: 0.2114731	total: 6m 18s	remaining: 1m 49s
# 776:	learn: 0.2114404	total: 6m 19s	remaining: 1m 48s
# 777:	learn: 0.2114129	total: 6m 19s	remaining: 1m 48s
# 778:	learn: 0.2113927	total: 6m 20s	remaining: 1m 47s
# 779:	learn: 0.2113676	total: 6m 20s	remaining: 1m 47s
# 780:	learn: 0.2113462	total: 6m 21s	remaining: 1m 46s
# 781:	learn: 0.2113181	total: 6m 22s	remaining: 1m 46s
# 825:	learn: 0.2098385	total: 6m 41s	remaining: 1m 24s
# 826:	learn: 0.2097988	total: 6m 42s	remaining: 1m 24s
# 827:	learn: 0.2097679	total: 6m 42s	remaining: 1m 23s
# 828:	learn: 0.2097400	total: 6m 43s	remaining: 1m 23s
# 829:	learn: 0.2097027	total: 6m 43s	remaining: 1m 22s
# 830:	learn: 0.2096640	total: 6m 44s	remaining: 1m 22s
# 831:	learn: 0.2096447	total: 6m 44s	remaining: 1m 21s
# 832:	learn: 0.2096279	total: 6m 45s	remaining: 1m 21s
# 833:	learn: 0.2095699	total: 6m 45s	remaining: 1m 20s
# 834:	learn: 0.2095603	total: 6m 46s	remaining: 1m 20s
# 835:	learn: 0.2094716	total: 6m 46s	remaining: 1m 19s
# 836:	learn: 0.2093686	total: 6m 47s	remaining: 1m 19s
# 837:	learn: 0.2093559	total: 6m 47s	remaining: 1m 18s
# 838:	learn: 0.2092318	total: 6m 48s	remaining: 1m 18s
# 839:	learn: 0.2092214	total: 6m 48s	remaining: 1m 17s
# 840:	learn: 0.2092118	total: 6m 48s	remaining: 1m 17s
# 841:	learn: 0.2091908	total: 6m 49s	remaining: 1m 16s
# 842:	learn: 0.2091784	total: 6m 49s	remaining: 1m 16s
# 843:	learn: 0.2091672	total: 6m 50s	remaining: 1m 15s
# 844:	learn: 0.2091431	total: 6m 50s	remaining: 1m 15s
# 845:	learn: 0.2091064	total: 6m 51s	remaining: 1m 14s
# 846:	learn: 0.2090876	total: 6m 51s	remaining: 1m 14s
# 847:	learn: 0.2090634	total: 6m 52s	remaining: 1m 13s
# 848:	learn: 0.2090600	total: 6m 52s	remaining: 1m 13s
# 849:	learn: 0.2090511	total: 6m 52s	remaining: 1m 12s
# 850:	learn: 0.2090308	total: 6m 53s	remaining: 1m 12s
# 851:	learn: 0.2090072	total: 6m 53s	remaining: 1m 11s
# 852:	learn: 0.2089377	total: 6m 54s	remaining: 1m 11s
# 853:	learn: 0.2089239	total: 6m 54s	remaining: 1m 10s
# 854:	learn: 0.2089175	total: 6m 55s	remaining: 1m 10s
# 855:	learn: 0.2088486	total: 6m 55s	remaining: 1m 9s
# 856:	learn: 0.2088139	total: 6m 56s	remaining: 1m 9s
# 857:	learn: 0.2087827	total: 6m 56s	remaining: 1m 8s
# 858:	learn: 0.2087630	total: 6m 57s	remaining: 1m 8s
# 859:	learn: 0.2087057	total: 6m 57s	remaining: 1m 7s
# 860:	learn: 0.2086900	total: 6m 58s	remaining: 1m 7s
# 861:	learn: 0.2086507	total: 6m 58s	remaining: 1m 6s
# 862:	learn: 0.2086403	total: 6m 58s	remaining: 1m 6s
# 863:	learn: 0.2086263	total: 6m 59s	remaining: 1m 6s
# 864:	learn: 0.2086098	total: 6m 59s	remaining: 1m 5s
# 865:	learn: 0.2085799	total: 7m	remaining: 1m 5s
# 866:	learn: 0.2085631	total: 7m	remaining: 1m 4s
# 867:	learn: 0.2085325	total: 7m 1s	remaining: 1m 4s
# 868:	learn: 0.2085018	total: 7m 1s	remaining: 1m 3s
# 869:	learn: 0.2084799	total: 7m 2s	remaining: 1m 3s
# 870:	learn: 0.2084729	total: 7m 2s	remaining: 1m 2s
# 871:	learn: 0.2084368	total: 7m 3s	remaining: 1m 2s
# 872:	learn: 0.2084029	total: 7m 3s	remaining: 1m 1s
# 873:	learn: 0.2083776	total: 7m 3s	remaining: 1m 1s
# 874:	learn: 0.2083493	total: 7m 4s	remaining: 1m
# 875:	learn: 0.2083141	total: 7m 4s	remaining: 1m
# 876:	learn: 0.2082640	total: 7m 5s	remaining: 59.6s
# 877:	learn: 0.2082413	total: 7m 5s	remaining: 59.2s
# 878:	learn: 0.2082100	total: 7m 6s	remaining: 58.7s
# 879:	learn: 0.2081476	total: 7m 6s	remaining: 58.2s
# 880:	learn: 0.2081117	total: 7m 7s	remaining: 57.7s
# 881:	learn: 0.2080920	total: 7m 7s	remaining: 57.2s
# 882:	learn: 0.2080831	total: 7m 7s	remaining: 56.7s
# 883:	learn: 0.2080644	total: 7m 8s	remaining: 56.2s
# 884:	learn: 0.2080580	total: 7m 8s	remaining: 55.7s
# 885:	learn: 0.2080318	total: 7m 9s	remaining: 55.2s
# 886:	learn: 0.2080054	total: 7m 9s	remaining: 54.7s
# 887:	learn: 0.2079890	total: 7m 10s	remaining: 54.3s
# 888:	learn: 0.2079242	total: 7m 10s	remaining: 53.8s
# 889:	learn: 0.2078813	total: 7m 11s	remaining: 53.3s
# 890:	learn: 0.2078728	total: 7m 11s	remaining: 52.8s
# 891:	learn: 0.2078223	total: 7m 11s	remaining: 52.3s
# 892:	learn: 0.2077951	total: 7m 12s	remaining: 51.8s
# 893:	learn: 0.2077488	total: 7m 12s	remaining: 51.3s
# 894:	learn: 0.2077219	total: 7m 13s	remaining: 50.8s
# 895:	learn: 0.2076886	total: 7m 13s	remaining: 50.4s
# 896:	learn: 0.2076620	total: 7m 14s	remaining: 49.9s
# 897:	learn: 0.2076258	total: 7m 14s	remaining: 49.4s
# 898:	learn: 0.2075848	total: 7m 15s	remaining: 48.9s
# 899:	learn: 0.2075532	total: 7m 15s	remaining: 48.4s
# 900:	learn: 0.2075322	total: 7m 16s	remaining: 47.9s
# 901:	learn: 0.2075158	total: 7m 16s	remaining: 47.4s
# 902:	learn: 0.2074763	total: 7m 16s	remaining: 46.9s
# 903:	learn: 0.2074547	total: 7m 17s	remaining: 46.5s
# 904:	learn: 0.2074236	total: 7m 17s	remaining: 46s
# 905:	learn: 0.2074185	total: 7m 18s	remaining: 45.5s
# 906:	learn: 0.2074079	total: 7m 18s	remaining: 45s
# 907:	learn: 0.2073693	total: 7m 19s	remaining: 44.5s
# 908:	learn: 0.2073344	total: 7m 19s	remaining: 44s
# 909:	learn: 0.2072633	total: 7m 20s	remaining: 43.5s
# 910:	learn: 0.2072496	total: 7m 20s	remaining: 43s
# 911:	learn: 0.2072171	total: 7m 20s	remaining: 42.5s
